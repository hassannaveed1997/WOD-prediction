# %%
import pandas as pd
import numpy as np
# to use preprocessing functions, add the path to current folder
import sys
sys.path.append("../../")
from modeling.preprocessing import convert_to_datetime, convert_units
# Out:
# /var/folders/0p/vxx15thx5pv6_xnkf32xgpzr0000gn/T/ipykernel_46895/4085923203.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('2023_BenchMarkStats_men3.csv')
df.head()
# Out:
#    Unnamed: 0       id               name Back Squat Chad1000x Clean and Jerk  \
# 0           0   469656      Jeffrey Adler     475 lb        --         377 lb
# 1           1   300638     Tola Morakinyo     500 lb        --         390 lb
# 2           2   676693     Colten Mertens     555 lb        --         335 lb
# 3           3   663689  Tyler Christophel         --        --             --
# 4           4  1031875    Roldan Goldbaum     445 lb        --         350 lb
#
#   Deadlift Fight Gone Bad Filthy 50  Fran Grace Helen L1 Benchmark  \
# 0   567 lb            511     15:17  2:02  1:16  7:18           --
# 1   615 lb             --        --    --    --    --           --
# 2   545 lb             --        --    --    --    --           --
# 3       --             --        --    --    --    --           --
# 4   515 lb             --        --  2:10  1:07    --           --
#
#   Max Pull-ups Run 5k  Snatch Sprint 400m
# 0           54  19:15  290 lb        0:59
# 1           --     --  340 lb          --
# 2           --     --  275 lb          --
# 3           --     --      --          --
# 4           --  18:00  280 lb        0:56

# %%
df = df.replace("--", np.nan)

# %%
exercise_cols = ['Back Squat', 'Chad1000x', 'Clean and Jerk',
       'Deadlift', 'Fight Gone Bad', 'Filthy 50', 'Fran', 'Grace', 'Helen',
       'L1 Benchmark', 'Max Pull-ups', 'Run 5k', 'Snatch', 'Sprint 400m']

# %% [markdown]
# ## Convert data types

# %%
# convert weight columns to float (in lb)
convert_units(df,type =  'weight', columns=["Deadlift", "Clean and Jerk","Back Squat","Snatch"])
# Out:
#        Unnamed: 0       id               name  Back Squat  Chad1000x  \
# 0               0   469656      Jeffrey Adler       475.0        NaN
# 1               1   300638     Tola Morakinyo       500.0        NaN
# 2               2   676693     Colten Mertens       555.0        NaN
# 3               3   663689  Tyler Christophel         NaN        NaN
# 4               4  1031875    Roldan Goldbaum       445.0        NaN
# ...           ...      ...                ...         ...        ...
# 77222       77222  1594361      Erik Davidson         NaN        NaN
# 77223       77223  1768926   Ammar El-wardani         NaN        NaN
# 77224       77224   205540     Doug Shinstrom       400.0        NaN
# 77225       77225  2240531     Daniel Nevarez         NaN        NaN
# 77226       77226   884354      Hwang Heegwan       335.0        NaN
#
#        Clean and Jerk  Deadlift  Fight Gone Bad  Filthy 50   Fran  Grace  \
# 0               377.0     567.0             NaN      917.0  122.0   76.0
# 1               390.0     615.0             NaN        NaN    NaN    NaN
# 2               335.0     545.0             NaN        NaN    NaN    NaN
# 3                 NaN       NaN             NaN        NaN    NaN    NaN
# 4               350.0     515.0             NaN        NaN  130.0   67.0
# ...               ...       ...             ...        ...    ...    ...
# 77222             NaN       NaN             NaN        NaN    NaN    NaN
# 77223             NaN       NaN             NaN        NaN    NaN    NaN
# 77224           297.0     455.0             NaN        NaN  193.0  133.0
# 77225             NaN       NaN             NaN        NaN    NaN    NaN
# 77226           245.0     395.0             NaN        NaN  235.0    NaN
#
#        Helen  L1 Benchmark  Max Pull-ups  Run 5k  Snatch  Sprint 400m
# 0      438.0           NaN          54.0  1155.0   290.0         59.0
# 1        NaN           NaN           NaN     NaN   340.0          NaN
# 2        NaN           NaN           NaN     NaN   275.0          NaN
# 3        NaN           NaN           NaN     NaN     NaN          NaN
# 4        NaN           NaN           NaN  1080.0   280.0         56.0
# ...      ...           ...           ...     ...     ...          ...
# 77222    NaN           NaN           NaN     NaN     NaN          NaN
# 77223    NaN           NaN           NaN     NaN     NaN          NaN
# 77224    NaN           NaN          25.0     NaN   215.0         98.0
# 77225    NaN           NaN           NaN     NaN     NaN          NaN
# 77226    NaN           NaN          22.0     NaN   175.0          NaN
#
# [77227 rows x 17 columns]

# %%
# convert time columns
def convert_to_timedelta_single(x):
    if pd.isnull(x):
        return pd.NaT
    if not isinstance(x, str):
        print(x)
        return pd.NaT
    # get last 5 characters (anything bigger is an error)
    try:
        x = x[-5:]
        full_str = "00:00:00"
        x = full_str[0:(8-len(x))] + x

        return pd.Timedelta(x)
    except:
        print(x)
        return pd.NaT

def convert_to_seconds(df, columns = None):
    if columns is None:
        columns = df.columns
    
    for col in columns:
        # if its an object or string
        if df[col].dtype == 'O':
            df[col] = df[col].apply(convert_to_timedelta_single)
            df[col] = df[col].dt.total_seconds()
    return df
time_cols = ["Fran",'Helen','Grace', 'Filthy 50', 'Fight Gone Bad', 'Sprint 400m', 'Run 5k','Chad1000x','L1 Benchmark']
convert_to_seconds(df, columns = time_cols)
# Out:
#        Unnamed: 0       id               name  Back Squat  Chad1000x  \
# 0               0   469656      Jeffrey Adler       475.0        NaN
# 1               1   300638     Tola Morakinyo       500.0        NaN
# 2               2   676693     Colten Mertens       555.0        NaN
# 3               3   663689  Tyler Christophel         NaN        NaN
# 4               4  1031875    Roldan Goldbaum       445.0        NaN
# ...           ...      ...                ...         ...        ...
# 77222       77222  1594361      Erik Davidson         NaN        NaN
# 77223       77223  1768926   Ammar El-wardani         NaN        NaN
# 77224       77224   205540     Doug Shinstrom       400.0        NaN
# 77225       77225  2240531     Daniel Nevarez         NaN        NaN
# 77226       77226   884354      Hwang Heegwan       335.0        NaN
#
#        Clean and Jerk  Deadlift  Fight Gone Bad  Filthy 50   Fran  Grace  \
# 0               377.0     567.0             NaN      917.0  122.0   76.0
# 1               390.0     615.0             NaN        NaN    NaN    NaN
# 2               335.0     545.0             NaN        NaN    NaN    NaN
# 3                 NaN       NaN             NaN        NaN    NaN    NaN
# 4               350.0     515.0             NaN        NaN  130.0   67.0
# ...               ...       ...             ...        ...    ...    ...
# 77222             NaN       NaN             NaN        NaN    NaN    NaN
# 77223             NaN       NaN             NaN        NaN    NaN    NaN
# 77224           297.0     455.0             NaN        NaN  193.0  133.0
# 77225             NaN       NaN             NaN        NaN    NaN    NaN
# 77226           245.0     395.0             NaN        NaN  235.0    NaN
#
#        Helen  L1 Benchmark  Max Pull-ups  Run 5k  Snatch  Sprint 400m
# 0      438.0           NaN          54.0  1155.0   290.0         59.0
# 1        NaN           NaN           NaN     NaN   340.0          NaN
# 2        NaN           NaN           NaN     NaN   275.0          NaN
# 3        NaN           NaN           NaN     NaN     NaN          NaN
# 4        NaN           NaN           NaN  1080.0   280.0         56.0
# ...      ...           ...           ...     ...     ...          ...
# 77222    NaN           NaN           NaN     NaN     NaN          NaN
# 77223    NaN           NaN           NaN     NaN     NaN          NaN
# 77224    NaN           NaN          25.0     NaN   215.0         98.0
# 77225    NaN           NaN           NaN     NaN     NaN          NaN
# 77226    NaN           NaN          22.0     NaN   175.0          NaN
#
# [77227 rows x 17 columns]

# %%
# convert reps to int
df['Max Pull-ups'] = df['Max Pull-ups'].astype(float)

# %% [markdown]
# ## Sanity checking data

# %%
for col in exercise_cols:
    print(f"col {col} : {df.loc[:,col].unique()[:10]}")

# print any that are not numbers
for col in exercise_cols:
   if df[col].dtype == 'O':
       print(f"NON numeric col {col}")
# Out:
# col Back Squat : [475.     500.     555.          nan 445.     435.     451.9471 425.
#  440.     535.    ]
# col Chad1000x : [  nan 3319. 3420. 3360. 3305. 4843. 4855. 3720. 4372. 3810.]
# col Clean and Jerk : [377.     390.     335.          nan 350.     370.     363.7623 360.
#  347.     375.    ]
# col Deadlift : [567.     615.     545.          nan 515.     530.     529.1088 550.
#  480.     540.    ]
# col Fight Gone Bad : [nan 15. 38. 44.  7.  1. 25. 21. 28. 50.]
# col Filthy 50 : [ 917.   nan  890. 1050. 1202.  905. 1157. 1145. 1310.  930.]
# col Fran : [122.  nan 130. 125. 127. 110. 135. 120. 126. 134.]
# col Grace : [ 76.  nan  67.  90.  70. 118.  75.  72. 105. 102.]
# col Helen : [438.  nan 405. 418. 435. 433.  71. 486. 420. 454.]
# col L1 Benchmark : [ nan 163. 213. 162. 180. 201. 191. 184. 211. 206.]
# col Max Pull-ups : [54. nan 75. 50. 82. 68. 60. 55. 70. 85.]
# col Run 5k : [1155.   nan 1080. 1052. 1160. 1136. 1105. 1142. 1196. 1140.]
# col Snatch : [290.     340.     275.          nan 280.     305.     297.6237 300.
#  265.     253.5313]
# col Sprint 400m : [59. nan 56. 54. 58. 61. 70. 67. 64. 52.]

# %%
df[exercise_cols].mean(axis = 0)
# Out:
# Back Squat         468.104702
# Chad1000x         3746.771951
# Clean and Jerk     327.717131
# Deadlift           525.140343
# Fight Gone Bad      21.440000
# Filthy 50         1480.865641
# Fran               243.537834
# Grace              180.139427
# Helen              578.966379
# L1 Benchmark       343.008065
# Max Pull-ups       321.001718
# Run 5k            1344.961331
# Snatch             271.522738
# Sprint 400m        110.932899
# dtype: float64

# %%
df.to_csv('2023_BenchMarkStats_men3_cleaned.csv', index = False)

# %%
# remove rows with all missing values
exercise_cols = ['Back Squat', 'Chad1000x', 'Clean and Jerk',
       'Deadlift', 'Fight Gone Bad', 'Filthy 50', 'Fran', 'Grace', 'Helen',
       'L1 Benchmark', 'Max Pull-ups', 'Run 5k', 'Snatch', 'Sprint 400m']
df = df.dropna(subset = exercise_cols, how = 'all')
df
# Out:
#        Unnamed: 0       id                 name  Back Squat  Chad1000x  \
# 0               0   469656        Jeffrey Adler    475.0000        NaN
# 1               1   300638       Tola Morakinyo    500.0000        NaN
# 2               2   676693       Colten Mertens    555.0000        NaN
# 4               4  1031875      Roldan Goldbaum    445.0000        NaN
# 5               5   327636     Samuel Cournoyer    435.0000        NaN
# ...           ...      ...                  ...         ...        ...
# 77216       77216  2176626      Brandon Medrano         NaN        NaN
# 77218       77218   566645  Christopher Pucella    285.0000        NaN
# 77221       77221  2325509         Юрий Матюхин    286.6006        NaN
# 77224       77224   205540       Doug Shinstrom    400.0000        NaN
# 77226       77226   884354        Hwang Heegwan    335.0000        NaN
#
#        Clean and Jerk  Deadlift  Fight Gone Bad  Filthy 50   Fran  Grace  \
# 0            377.0000   567.000             NaN      917.0  122.0   76.0
# 1            390.0000   615.000             NaN        NaN    NaN    NaN
# 2            335.0000   545.000             NaN        NaN    NaN    NaN
# 4            350.0000   515.000             NaN        NaN  130.0   67.0
# 5            370.0000   530.000             NaN        NaN  125.0   90.0
# ...               ...       ...             ...        ...    ...    ...
# 77216             NaN       NaN             NaN        NaN    NaN    NaN
# 77218        205.0000   335.000             NaN        NaN  390.0    NaN
# 77221        231.4851   330.693             NaN        NaN    NaN    NaN
# 77224        297.0000   455.000             NaN        NaN  193.0  133.0
# 77226        245.0000   395.000             NaN        NaN  235.0    NaN
#
#        Helen  L1 Benchmark  Max Pull-ups  Run 5k    Snatch  Sprint 400m
# 0      438.0           NaN          54.0  1155.0  290.0000         59.0
# 1        NaN           NaN           NaN     NaN  340.0000          NaN
# 2        NaN           NaN           NaN     NaN  275.0000          NaN
# 4        NaN           NaN           NaN  1080.0  280.0000         56.0
# 5        NaN           NaN           NaN     NaN  305.0000          NaN
# ...      ...           ...           ...     ...       ...          ...
# 77216    NaN           NaN           NaN  1476.0       NaN         77.0
# 77218  536.0           NaN          32.0  1160.0       NaN         68.0
# 77221    NaN           NaN           NaN   352.0  165.3465          NaN
# 77224    NaN           NaN          25.0     NaN  215.0000         98.0
# 77226    NaN           NaN          22.0     NaN  175.0000          NaN
#
# [36010 rows x 17 columns]
